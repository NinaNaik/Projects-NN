# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:\\Users\\Nina\\OneDrive\\Desktop\\amazon_all_electronics_data.csv')

# %%
df.head()
# Out:
#                                         Product_Name    Price  Rating  \
# 0                   Apple iPhone 15 (128 GB) - Black  47999.0     4.5
# 1                    Apple iPhone 15 (128 GB) - Blue  48499.0     4.5
# 2  Samsung Galaxy S24 Ultra 5G AI Smartphone with...  75749.0     4.5
# 3  Samsung Original 25W Type-C Travel Adaptor Wit...    889.0     4.4
# 4  realme NARZO 80 Lite 5G (Crystal Purple, 6GB+1...   9898.0     4.2
#
#    Review_Count        ASIN  \
# 0          6013  B0CHX1W1XY
# 1          6013  B0CHX2F5QT
# 2          4419  B0CS5XW6TN
# 3         44669  B0D2R2MXXJ
# 4          1242  B0F9TT7Z5Q
#
#                                          Product_URL Availability
# 0  https://www.amazon.in/Apple-iPhone-15-128-GB/d...     In Stock
# 1  https://www.amazon.in/Apple-iPhone-15-128-GB/d...     In Stock
# 2  https://www.amazon.in/Samsung-Galaxy-Smartphon...     In Stock
# 3  https://www.amazon.in/Samsung-Original-Type-C-...     In Stock
# ...

# %%
df.tail()
# Out:
#                                            Product_Name   Price  Rating  \
# 9313  Zapcase Back Case Cover for Samsung Galaxy S24...   259.0     4.1
# 9314  GadgetBite Stylus Pen for Android Tablet & iOS...   209.0     4.3
# 9315  HIFFIN 6x9 Ft, White Professional Backdrop for...   349.0     3.8
# 9316  ESR Geo iPad Pencil Findmy for Apple Pencil Co...  1986.0     4.3
# 9317  Hi-PLASST PINS & Plugs Hi-PLASST 2-Pin Flexibl...   247.0     3.8
#
#       Review_Count        ASIN  \
# 9313           229  B0CST3PRSM
# 9314            66  B0F79G5ZDC
# 9315          2215  B09CV33W2S
# 9316          1110  B0DM5Z2WXD
# 9317           698  B07YCS2M63
#
#                                             Product_URL Availability
# 9313  https://www.amazon.in/Zapcase-Samsung-Compatib...     In Stock
# 9314  https://www.amazon.in/GadgetBite-Touchscreen-C...     In Stock
# 9315  https://www.amazon.in/Professional-Backdrop-Ba...     In Stock
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9318 entries, 0 to 9317
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_Name  9318 non-null   object
#  1   Price         9252 non-null   float64
#  2   Rating        9282 non-null   float64
#  3   Review_Count  9318 non-null   int64
#  4   ASIN          9318 non-null   object
#  5   Product_URL   9318 non-null   object
#  6   Availability  9318 non-null   object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 509.7+ KB

# %%
df.columns
# Out:
# Index(['Product_Name', 'Price', 'Rating', 'Review_Count', 'ASIN',
#        'Product_URL', 'Availability'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9318, step=1)

# %%
df.isnull().sum()
# Out:
# Product_Name     0
# Price           66
# Rating          36
# Review_Count     0
# ASIN             0
# Product_URL      0
# Availability     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                Price       Rating   Review_Count
# count    9252.000000  9282.000000    9318.000000
# mean     3934.530942     4.099214    7227.565465
# std     10653.192705     0.317521   22582.406507
# min        41.000000     1.000000       0.000000
# 25%       269.000000     3.900000     297.000000
# 50%       615.500000     4.100000    1112.000000
# 75%      1699.000000     4.300000    4318.500000
# max    139990.000000     5.000000  427173.000000

# %%
df['Price']=df['Price'].fillna(df['Price'].mean())

# %%
df['Rating']=df['Rating'].fillna(df['Rating'].mean())

# %% [markdown]
# # DATA VISUALIZATION

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# PRICE DISTRIBUTION

# %%
# Histplot-Price Distribution
plt.figure(figsize=(10,6))
sns.histplot(df['Price'],kde=True,color='blue')
plt.title('Price Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
# Histplot-Rating Distribution
plt.figure(figsize=(10, 6))
sns.histplot(df['Rating'], kde=True, color='green')
plt.title('Rating Distribution')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
# Histplot-Review Count Distribution
plt.figure(figsize=(10, 6))
sns.histplot(df['Review_Count'], kde=True, color='red')
plt.title('Review Count Distribution')
plt.xlabel('Review Count')
plt.ylabel('Frequency')
plt.show()

# %%
# Boxplot-Detecting Outliers for Price
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Price'])
plt.title('Price Boxplot')
plt.show()

# %%
# BoxPlot-Detecting outliers for Ratings
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Rating'])
plt.title('Rating Boxplot')
plt.show()

# %%
# Correlation Matrix-Correlation between Price, Rating & Review Count
corr_matrix = df[['Price', 'Rating', 'Review_Count']].corr()
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
# Countplot for Availability of different categories
plt.figure(figsize=(10, 6))
sns.countplot(x='Availability', data=df)
plt.title('Availability Count')
plt.show()

# %%
# Scatter plot for Price vs Rating to understand relationship between price and rating
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['Price'], y=df['Rating'], alpha=0.7)
plt.title('Price vs Rating')
plt.xlabel('Price')
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# # FEATURE ENGINEERING

# %% [markdown]
# # Drop unneccesary columns

# %%
df_model=df.drop(columns=['Product_URL','ASIN'])

# %% [markdown]
# # One Hot Encoding Categorical Variables

# %%
df_model=pd.get_dummies(df_model,drop_first=True)

# %% [markdown]
# # Converting Price, Rating & Review Count to Numeric

# %%
df['Price']=pd.to_numeric(df['Price'],errors='coerce')

# %%
df['Rating']=pd.to_numeric(df['Rating'],errors='coerce')

# %%
df['Review_Count']=pd.to_numeric(df['Review_Count'],errors='coerce')

# %% [markdown]
# # MACHINE LEARNING

# %%
# Define Features(X) and Target Variables(Y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
# REGRESSION MODELS
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,r2_score

# %%
X=df_model.drop(columns=['Price'])
y=df_model['Price']

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
X_Scaled=scaler.fit_transform(X)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Data Splitting into Training and Testing

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1111)

# %%
print(X_test.shape)
# Out:
# (1864, 9160)

# %% [markdown]
# # Initialize the Model

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Train the Model

# %%
rf_model=RandomForestRegressor(n_estimators=100,random_state=42)
print(rf_model)
# Out:
# RandomForestRegressor(random_state=42)

# %%
rf_model.fit(X_train,y_train)

# %% [markdown]
# # PREDICTIONS

# %%
y_pred=rf_model.predict(X_test)

# %%
y_pred

# %%
print(y_pred)

# %%
y_pred=rf_model.predict(X_test)
y_pred
