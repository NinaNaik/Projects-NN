# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# %%
print("Pandas imported successfully")
# Out:
# Pandas imported successfully

# %%
df=pd.read_csv("C:\\Users\\Nina\\OneDrive\\Desktop\\amazon_all_electronics_data.csv")

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
print(df.shape)
# Out:
# (9318, 7)

# %%
df.head()
# Out:
#                                         Product_Name    Price  Rating  \
# 0                   Apple iPhone 15 (128 GB) - Black  47999.0     4.5
# 1                    Apple iPhone 15 (128 GB) - Blue  48499.0     4.5
# 2  Samsung Galaxy S24 Ultra 5G AI Smartphone with...  75749.0     4.5
# 3  Samsung Original 25W Type-C Travel Adaptor Wit...    889.0     4.4
# 4  realme NARZO 80 Lite 5G (Crystal Purple, 6GB+1...   9898.0     4.2
#
#    Review_Count        ASIN  \
# 0          6013  B0CHX1W1XY
# 1          6013  B0CHX2F5QT
# 2          4419  B0CS5XW6TN
# 3         44669  B0D2R2MXXJ
# 4          1242  B0F9TT7Z5Q
#
#                                          Product_URL Availability
# 0  https://www.amazon.in/Apple-iPhone-15-128-GB/d...     In Stock
# 1  https://www.amazon.in/Apple-iPhone-15-128-GB/d...     In Stock
# 2  https://www.amazon.in/Samsung-Galaxy-Smartphon...     In Stock
# 3  https://www.amazon.in/Samsung-Original-Type-C-...     In Stock
# ...

# %%
df_model = df.drop(columns=['Product_Name', 'Product_URL', 'ASIN', 'Availability'])

# %%
df['Price']=pd.to_numeric(df['Price'],errors='coerce')
df['Rating']=pd.to_numeric(df['Rating'],errors='coerce')
df['Review_Count']=pd.to_numeric(df['Review_Count'],errors='coerce')

# %%
X=df_model.drop(columns=['Price'])
y=df_model['Price']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
X_Scaled=scaler.fit_transform(X)

# %%
# REGRESSION MODELS
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,r2_score

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1111)

# %%
print(X_test.shape)
# Out:
# (1864, 2)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
rf_model=RandomForestRegressor(n_estimators=100,random_state=42)
print(rf_model)
# Out:
# RandomForestRegressor(random_state=42)

# %%
print(pd.isnull(y_train).sum())
# Out:
# 55

# %%
train_df = pd.concat([X_train, y_train], axis=1)

# %%
train_df = train_df.dropna(subset=[y_train.name])

# %%
X_train_clean = train_df.drop(columns=[y_train.name])
y_train_clean = train_df[y_train.name]

# %%
train_df = pd.concat([X_train_clean, y_train], axis=1)

# %%
train_df = train_df.dropna(subset=[y_train.name])
train_df
# Out:
#       Rating  Review_Count   Price
# 1393     4.0        1291.0  1549.0
# 8511     3.9        1148.0   179.0
# 2145     4.0       15448.0   233.0
# 8982     4.2         590.0   254.0
# 3299     3.9        2397.0   272.0
# ...      ...           ...     ...
# 788      4.4         716.0   499.0
# 4248     4.5        8917.0   814.0
# 8866     2.0          85.0   664.0
# 2789     4.3       14385.0  8999.0
# 311      4.0       16883.0   179.0
#
# [7399 rows x 3 columns]

# %%
X_train_clean = train_df.drop(columns=[y_train.name])
y_train_clean = train_df[y_train.name]

# %%
y_train_filled = y_train.fillna(y_train.mode()[0])
rf_model.fit(X_train, y_train_filled)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred=rf_model.predict(X_test)
y_pred
# Out:
# array([3648.68416667, 4035.75127758,  447.7       , ...,  584.80765873,
#        1147.28928571, 3661.49      ])

# %% [markdown]
# # DEALING WITH NANs: in y_test and y_pred

# %%
df_model = df.drop(columns=['Product_Name', 'Product_URL', 'ASIN', 'Availability'], errors='ignore')

# %%
print("NaNs in y_test:", y_test.isna().sum())
# Out:
# NaNs in y_test: 11

# %%
print("NaNs in y_pred:", pd.Series(y_pred).isna().sum())
# Out:
# NaNs in y_pred: 0

# %%
y_test_clean = pd.Series(y_test).reset_index(drop=True)
y_pred_clean = pd.Series(y_pred).reset_index(drop=True)

# %%
df_combined = pd.concat([y_test_clean, y_pred_clean], axis=1).dropna()

# %%
y_test_clean = df_combined.iloc[:, 0]
y_pred_clean = df_combined.iloc[:, 1]

# %% [markdown]
# # EVALUATE THE MODEL

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test_clean, y_pred_clean)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 72607294.32779033

# %%
print("y_test shape:", y_test.shape)
print("y_pred shape:", y_pred.shape)
# Out:
# y_test shape: (1864,)
# y_pred shape: (1864,)
